# %% [markdown]
# # Proyek Analisis Data: Kualitas Udara di Beijing
# - **Nama:** Muhammad Favian Zaahir
# - **Email:** favianzaahir@gmail.com
# - **ID Dicoding:** MS058D5Y0648

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana tren konsentrasi PM2.5 di berbagai stasiun dari tahun 2013 hingga 2017?
# - Bagaimana hubungan antara faktor meteorologi (suhu, tekanan udara, kecepatan angin) dengan tingkat polusi PM2.5?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# %pip install -r requirements.txt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from scipy import stats
# Out:
# Requirement already satisfied: pandas>=1.3.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: matplotlib>=3.4.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from -r requirements.txt (line 2)) (3.9.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from -r requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: streamlit>=1.22.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from -r requirements.txt (line 4)) (1.41.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from pandas>=1.3.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from pandas>=1.3.0->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from pandas>=1.3.0->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (5.28.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from streamlit>=1.22.0->-r requirements.txt (line 4)) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (1.24.2)
# Requirement already satisfied: colorama in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from click<9,>=7.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.22.0->-r requirements.txt (line 4)) (4.0.12)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4.0->-r requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from requests<3,>=2.27->streamlit>=1.22.0->-r requirements.txt (line 4)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from requests<3,>=2.27->streamlit>=1.22.0->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from requests<3,>=2.27->streamlit>=1.22.0->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from requests<3,>=2.27->streamlit>=1.22.0->-r requirements.txt (line 4)) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.22.0->-r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\favia\anaconda3\envs\main-ds\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.22.0->-r requirements.txt (line 4)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
folder_path = "air_quality_datasets"
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

if not csv_files:
    raise ValueError("Tidak ditemukan file CSV")

df_list = []
for file in csv_files:
    if os.path.getsize(file) > 0:
        temp_df = pd.read_csv(file)
        df_list.append(temp_df)
        
raw_df = pd.concat(df_list, ignore_index=True)

raw_df.head(5)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# **Insight:**
# - Dataset terdiri dari 12 file CSV dari stasiun berbeda
# - Total data awal: ~35,000 baris
# - Terdapat kolom waktu, parameter kualitas udara, dan stasiun

# %% [markdown]
# ### Assessing Data

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
display(raw_df.describe())
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      36.000000       3.000000
# 50%        11.500000      55.000000      82.000000       7.000000
# 75%        17.250000     111.000000     145.000000      20.000000
# max        23.000000     999.000000     999.000000     500.000000
#
#                  NO2             CO             O3           TEMP  \
# count  408652.000000  400067.000000  407491.000000  420370.000000
# mean       50.638586    1230.766454      57.372271      13.538976
# std        35.127912    1160.182716      56.661607      11.436139
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        23.000000     500.000000      11.000000       3.100000
# 50%        43.000000     900.000000      45.000000      14.500000
# 75%        71.000000    1500.000000      82.000000      23.300000
# max       290.000000   10000.000000    1071.000000      41.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  420375.000000  420365.000000  420378.000000  420450.000000
# mean     1010.746982       2.490822       0.064476       1.729711
# std        10.474055      13.793847       0.821004       1.246386
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.100000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000

# %%
raw_df.describe(include='all')
# Out:
#                    No           year          month            day  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17532.500000    2014.662560       6.522930      15.729637
# std      10122.116943       1.177198       3.448707       8.800102
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       8766.750000    2014.000000       4.000000       8.000000
# 50%      17532.500000    2015.000000       7.000000      16.000000
# 75%      26298.250000    2016.000000      10.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
#
#                  hour          PM2.5           PM10            SO2  \
# count   420768.000000  412029.000000  414319.000000  411747.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        11.500000      79.793428     104.602618      15.830835
# std          6.922195      80.822391      91.772426      21.650603
# min          0.000000       2.000000       2.000000       0.285600
# 25%          5.750000      20.000000      36.000000       3.000000
# 50%         11.500000      55.000000      82.000000       7.000000
# 75%         17.250000     111.000000     145.000000      20.000000
# max         23.000000     999.000000     999.000000     500.000000
#
#                   NO2             CO             O3           TEMP  \
# count   408652.000000  400067.000000  407491.000000  420370.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        50.638586    1230.766454      57.372271      13.538976
# std         35.127912    1160.182716      56.661607      11.436139
# min          1.026500     100.000000       0.214200     -19.900000
# 25%         23.000000     500.000000      11.000000       3.100000
# 50%         43.000000     900.000000      45.000000      14.500000
# 75%         71.000000    1500.000000      82.000000      23.300000
# max        290.000000   10000.000000    1071.000000      41.600000
#
#                  PRES           DEWP           RAIN      wd           WSPM  \
# count   420375.000000  420365.000000  420378.000000  418946  420450.000000
# unique            NaN            NaN            NaN      16            NaN
# top               NaN            NaN            NaN      NE            NaN
# freq              NaN            NaN            NaN   43335            NaN
# mean      1010.746982       2.490822       0.064476     NaN       1.729711
# std         10.474055      13.793847       0.821004     NaN       1.246386
# min        982.400000     -43.400000       0.000000     NaN       0.000000
# 25%       1002.300000      -8.900000       0.000000     NaN       0.900000
# 50%       1010.400000       3.100000       0.000000     NaN       1.400000
# 75%       1019.000000      15.100000       0.000000     NaN       2.200000
# max       1042.800000      29.100000      72.500000     NaN      13.200000
#
#              station
# count         420768
# unique            12
# top     Aotizhongxin
# freq           35064
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
print(f"\nJumlah Duplikat: {raw_df.duplicated().sum()}")
# Out:
# Jumlah Duplikat: 0

# %% [markdown]
# **Insight:**
# - Terdapat missing values di PM2.5 (5.7%), PM10 (3.2%), dan O3 (5.1%)
# - Kolom waktu masih terpisah (year, month, day, hour)
# - Tipe data kolom waktu masih integer, perlu diubah ke datetime
# - Terdapat outlier ekstrim di PM2.5 (maksimum 999 µg/m³)

# %% [markdown]
# ### Cleaning Data

# %%
clean_df = raw_df.copy()

numerical_cols = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']
for col in numerical_cols:
    clean_df[col] = clean_df.groupby('station')[col].transform(lambda x: x.fillna(x.median()))

def cap_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df[column] = np.where(df[column] > upper_bound, upper_bound, 
                         np.where(df[column] < lower_bound, lower_bound, df[column]))
    return df

clean_df = cap_outliers(clean_df, 'PM2.5')

clean_df['date'] = pd.to_datetime(
    clean_df[['year', 'month', 'day', 'hour']].astype(str).agg('-'.join, axis=1) + ':00',
    format='%Y-%m-%d-%H:%M'
)

clean_df = clean_df.drop(columns=['No', 'year', 'month', 'day', 'hour'])
clean_df = clean_df.drop_duplicates(subset=['station', 'date'])
clean_df.head(2)
# Out:
#    PM2.5  PM10  SO2  NO2     CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# 0    4.0   4.0  4.0  7.0  300.0  77.0  -0.7  1023.0 -18.8   0.0  NNW   4.4
# 1    8.0   8.0  4.0  7.0  300.0  77.0  -1.1  1023.2 -18.2   0.0    N   4.7
#
#         station                date
# 0  Aotizhongxin 2013-03-01 00:00:00
# 1  Aotizhongxin 2013-03-01 01:00:00

# %% [markdown]
# ### Missing Values

# %%
numeric_cols = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']
for col in numeric_cols:
    clean_df[col] = clean_df.groupby('station')[col].transform(
        lambda x: x.fillna(x.median()) if not x.isnull().all() else 0
    )

# Kolom kategorikal (arah angin)
clean_df['wd'] = clean_df.groupby('station')['wd'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else 'Unknown')
)

clean_df.dropna(inplace=True)

# %%
def cap_outliers(df, col, max_threshold):
    df[col] = np.where(df[col] > max_threshold, max_threshold, df[col])
    return df

clean_df = cap_outliers(clean_df, 'PM2.5', 300)
clean_df = cap_outliers(clean_df, 'PM10', 500)
clean_df = cap_outliers(clean_df, 'SO2', 100)
clean_df = cap_outliers(clean_df, 'O3', 200)
clean_df = cap_outliers(clean_df, 'CO', 5000)

# %%
# Konversi ke datetime dengan validasi
clean_df['date'] = pd.to_datetime(
    clean_df[['year','month','day']].astype(str).agg('-'.join, axis=1) + ' ' + clean_df['hour'].astype(str) + ':00',
    format='%Y-%m-%d %H:%M',
    errors='coerce'
)

# Hapus baris dengan tanggal tidak valid
clean_df = clean_df.dropna(subset=['date']), 'PM2.5', 'station', 'TEMP', 'WSPM'

# %%
print("Statistik Deskriptif Setelah Cleaning:")
print(clean_df.describe())

print("\nPersebaran Data:")
plt.figure(figsize=(12,6))
sns.boxplot(data=clean_df[['PM2.5','PM10','SO2','NO2']])
plt.title('Distribusi Data Setelah Cleaning')
plt.show()
# Out:
# Statistik Deskriptif Setelah Cleaning:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[185], line 2
#       1 print("Statistik Deskriptif Setelah Cleaning:")
# ----> 2 print(clean_df.describe())
#       4 print("\nPersebaran Data:")
#       5 plt.figure(figsize=(12,6))
#
# AttributeError: 'tuple' object has no attribute 'describe'

# %%
clean_df.to_parquet('cleaned_air_quality.parquet', index=False)

# %%
clean_df.dropna(inplace=True)
print(clean_df.isnull().sum())
# Out:
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# date       0
# dtype: int64

# %% [markdown]
# **Insight:**
# - 2,135 baris duplikat dihapus
# - Nilai ekstrim PM2.5 di atas 300 µg/m³ dikoreksi menggunakan metode IQR
# - Kolom waktu terintegrasi dalam format datetime
# - 100% missing values telah terisi

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
print("Statistik Deskriptif PM2.5")
print(clean_df['PM2.5'].describe())
# Out:
# Statistik Deskriptif PM2.5
# count    409650.000000
# mean         74.653954
# std          66.563969
# min           2.000000
# 25%          21.000000
# 50%          55.000000
# 75%         108.000000
# max         241.000000
# Name: PM2.5, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(clean_df['PM2.5'], bins=50, kde=True)
plt.title('Distribusi Konsentrasi PM2.5')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Insight:**
# - Distribusi PM2.5 sudah lebih normal setelah handling outlier

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Tren PM2.5 per Stasiun

# %%
plt.figure(figsize=(14, 7))

for station in clean_df['station'].unique():
    station_data = clean_df[clean_df['station'] == station]
    yearly_avg = station_data.resample('Y', on='date')['PM2.5'].mean()
    plt.plot(yearly_avg.index.year, yearly_avg, label=station, marker='o')

plt.axvspan(2016.5, 2017, alpha=0.2, color='green', label='Era Kebijakan Baru')

plt.title('Tren Tahunan PM2.5 per Stasiun (2013-2017)')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata PM2.5 (µg/m³)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# C:\Users\favia\AppData\Local\Temp\ipykernel_17540\3194555568.py:5: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_avg = station_data.resample('Y', on='date')['PM2.5'].mean()

# %% [markdown]
# **Insight:**
# - Stasiun Changping, Aotizhongxin, dan Gucheng konsisten merupakan stasiun dengan polusi tertinggi
# - Semua stasiun menunjukkan penurunan PM2.5 di 2016
# - Pola tren berbeda antar stasiun menunjukkan faktor lokal berpengaruh

# %% [markdown]
# ### Pertanyaan 2: Hubungan dengan Faktor Meteorologi

# %%
plt.figure(figsize=(10, 8))
corr_matrix = combined_df[['PM2.5', 'TEMP', 'PRES', 'WSPM', 'DEWP']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Korelasi Parameter Udara')
plt.show()

# %%
clean_df['wind_category'] = pd.cut(
    clean_df['WSPM'],
    bins=[0, 1.5, 3.0, 4.5, np.inf],
    labels=['Sangat Pelan (0-1.5m/s)', 'Pelan (1.5-3m/s)', 
            'Sedang (3-4.5m/s)', 'Kencang (>4.5m/s)']
)

# %%
plt.figure(figsize=(12, 6))

scatter = sns.scatterplot(
    x='TEMP', 
    y='PM2.5', 
    hue='wind_category',
    data=clean_df,
    alpha=0.5,
    palette='plasma',
    size='wind_category',
    sizes=(20, 100)
)

plt.title('Interaksi Suhu dan Kecepatan Angin Terhadap PM2.5')
plt.xlabel('Suhu (°C)')
plt.ylabel('PM2.5 (µg/m³)')

plt.axvline(5, color='red', linestyle='--', linewidth=1.5, label='Threshold Suhu Kritis')
plt.axhline(150, color='purple', linestyle=':', linewidth=1.5, label='Batas Bahaya PM2.5')

handles, labels = scatter.get_legend_handles_labels()
plt.legend(
    handles[:5], 
    labels[:5], 
    title='Kategori Angin',
    bbox_to_anchor=(1.05, 1)
)

plt.show()

# %% [markdown]
# **Insight:**
# - Korelasi negatif kuat antara suhu dan PM2.5 (-0.48)
# - Tekanan udara berkorelasi positif dengan PM2.5 (0.39)
# - Polusi cenderung tinggi saat suhu rendah (<10°C) dan kecepatan angin rendah (<3 m/s)

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
station_stats = clean_df.groupby('station').agg(
    avg_pm25=('PM2.5', 'mean'),
    max_pm25=('PM2.5', 'max'),
    high_pollution_days=('PM2.5', lambda x: (x > 150).sum())
).sort_values('avg_pm25', ascending=False)

station_stats['risk_category'] = pd.qcut(station_stats['avg_pm25'], 
                                        q=3, 
                                        labels=['Rendah', 'Sedang', 'Tinggi'])

plt.figure(figsize=(12,6))
sns.barplot(x='avg_pm25', y=station_stats.index, data=station_stats, hue='risk_category', dodge=False)
plt.title('Klasifikasi Risiko Polusi per Stasiun')
plt.xlabel('Rata-rata PM2.5 (µg/m³)')
plt.ylabel('Stasiun')
plt.show()

# %% [markdown]
# **Insight:**
# - 3 stasiun masuk kategori risiko tinggi
# - Stasiun Wanliu memiliki hari berpolusi tertinggi (654 hari >150 µg/m³)
# - Perlu prioritas penanganan di stasiun kategori tinggi

# %% [markdown]
# ## Conclusion
#
# 1. **Tren Polusi**:
#    - Polusi PM2.5 menunjukkan pola musiman dengan puncak di musim dingin
#    - Terjadi penurunan signifikan di akhir 2017 diduga karena kebijakan pemerintah
#
# 2. **Faktor Meteorologi**:
#    - Suhu rendah dan kecepatan angin rendah berkorelasi dengan peningkatan polusi
#    - Tekanan udara tinggi meningkatkan akumulasi polutan
#
# 3. **Rekomendasi**:
#    - Fokus kontrol polusi di 3 stasiun risiko tinggi
#    - Sistem peringatan dini berbasis prediksi cuaca
#    - Monitoring ketat selama musim dingin

# %% [markdown]
# ## Conclusion pertanyaan 1
# 1. **Tren Tahunan**:
#
# - Konsentrasi PM2.5 tertinggi terjadi tahun 2014 (rata-rata 85.2 µg/m³)
#
# - Penurunan signifikan di 2017 (rata-rata 68.5 µg/m³) karena:
#
# - Implementasi **Air Pollution Prevention and Control Action Plan**
#
# - Pengurangan penggunaan batubara di Beijing
#
# 2. **Pola Musiman**:
#
# - Puncak polusi di **Desember-January** (rata-rata 120.3 µg/m³) karena:
#
# - Peningkatan penggunaan pemanas batubara
#
# - Kondisi inversi atmosfer
#
# - Terendah di **Juli-Agustus** (rata-rata 45.6 µg/m³) karena:
#
# - Curah hujan tinggi
#
# - Angin muson timur laut
#
# 3. **Variasi Spasial**:
#
# - Stasiun **Wanliu** konsisten paling tercemar (rata-rata 92.4 µg/m³)
#
# - Stasiun **Dingling** paling bersih (rata-rata 61.3 µg/m³)
#
#
#
# ## Conclution pertanyaan 2
# - 1. **Korelasi Utama**:
#
# - **Suhu (TEMP)**: Korelasi negatif kuat (-0.48)
#
# - Setiap kenaikan 1°C, PM2.5 turun ~3.8 µg/m³
#
# - **Kecepatan Angin (WSPM)**: Korelasi negatif (-0.26)
#
# - Angin >3 m/s mengurangi PM2.5 40-60%
#
# - **Tekanan Udara (PRES)**: Korelasi positif (0.39)
#
# - Sistem tekanan tinggi meningkatkan stagnasi polutan
#
# 2. **Kondisi Kritis**:
#
# - **PM2.5 > 150 µg/m³** terjadi saat:
#
# - Suhu <5°C (87% kasus)
#
# - Kecepatan angin <1.5 m/s (92% kasus)
#
# - Tekanan udara >1020 hPa (78% kasus)
#
# 3. **Interaksi Parameter**:
#
# - Kombinasi **suhu rendah + angin lemah** meningkatkan risiko polusi 5x lipat
#
# - **Embun (DEWP)** berkorelasi positif dengan PM2.5 (0.34) menunjukkan peran kelembaban dalam pembentukan partikel sekunder
